# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, Flatten, BatchNormalization
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import SGD
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# Load and preprocess data
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

# Define the indices for cats and dogs
cat_index = 3
dog_index = 5

# Filter data to only include cats and dogs
train_filter = (y_train.flatten() == cat_index) | (y_train.flatten() == dog_index)
test_filter = (y_test.flatten() == cat_index) | (y_test.flatten() == dog_index)

x_train, y_train = x_train[train_filter], y_train[train_filter]
x_test, y_test = x_test[test_filter], y_test[test_filter]

# Map labels to binary (0 for cats, 1 for dogs)
y_train = (y_train == dog_index).astype(int)
y_test = (y_test == dog_index).astype(int)

# Normalize pixel values
def normalize(x):
    x = x.astype('float32') / 255.0
    return x

x_train = normalize(x_train)
x_test = normalize(x_test)

# Split data into training and validation sets
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.5, random_state=0)

# Create data augmentation generator
datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True
)
datagen.fit(x_train)

# Model definition
weight_decay = 1e-4
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', padding='same', kernel_regularizer=tf.keras.regularizers.l2(weight_decay), input_shape=(32, 32, 3)),
    BatchNormalization(),
    Conv2D(32, (3, 3), activation='relu', kernel_regularizer=tf.keras.regularizers.l2(weight_decay), padding='same'),
    BatchNormalization(),
    MaxPooling2D((2, 2)),
    Dropout(0.2),
    Conv2D(64, (3, 3), activation='relu', kernel_regularizer=tf.keras.regularizers.l2(weight_decay), padding='same'),
    BatchNormalization(),
    Conv2D(64, (3, 3), activation='relu', kernel_regularizer=tf.keras.regularizers.l2(weight_decay), padding='same'),
    BatchNormalization(),
    MaxPooling2D((2, 2)),
    Dropout(0.3),
    Conv2D(128, (3, 3), activation='relu', kernel_regularizer=tf.keras.regularizers.l2(weight_decay), padding='same'),
    BatchNormalization(),
    Conv2D(128, (3, 3), activation='relu', kernel_regularizer=tf.keras.regularizers.l2(weight_decay), padding='same'),
    BatchNormalization(),
    MaxPooling2D((2, 2)),
    Dropout(0.3),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(1, activation='sigmoid')  # Binary classification output
])

# Compile the model
opt = SGD(learning_rate=0.001, momentum=0.9)
model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])

# Training and evaluation
def results(model):
    epoch = 100
    r = model.fit(datagen.flow(x_train, y_train, batch_size=32), epochs=epoch, steps_per_epoch=len(x_train) // 32, validation_data=(x_val, y_val), verbose=1)
    
    # Evaluate model
    y_pred = model.predict(x_test)
    y_test_classes = y_test
    y_pred_classes = (y_pred > 0.5).astype(int)
    
    # Confusion Matrix
    conf_matrix = confusion_matrix(y_test_classes, y_pred_classes)
    
    # Classification Report
    class_report = classification_report(y_test_classes, y_pred_classes, target_names=['Cat', 'Dog'], output_dict=True)

    # Model Evaluation
    acc = model.evaluate(x_test, y_test)
    print("Test set loss:", acc[0])
    print("Test set accuracy:", acc[1] * 100)
    
    # Plot accuracy
    epoch_range = range(1, epoch + 1)
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(epoch_range, r.history['accuracy'])
    plt.plot(epoch_range, r.history['val_accuracy'])
    plt.title('Classification Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='lower right')
    
    # Plot loss
    plt.subplot(1, 2, 2)
    plt.plot(epoch_range, r.history['loss'])
    plt.plot(epoch_range, r.history['val_loss'])
    plt.title('Model Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='lower right')
    plt.show()

    # Confusion Matrix Heatmap
    plt.figure(figsize=(8, 6))
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Cat', 'Dog'], yticklabels=['Cat', 'Dog'])
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')
    plt.show()
    
    # Classification Report
    report_df = pd.DataFrame(class_report).transpose()
    print("\nClassification Report:")
    print(report_df)
    
    # Model Summary
    print("\nModel Summary:")
    model.summary()

    # Display some images from the test set
    plt.figure(figsize=(10, 10))
    for i in range(10):
        plt.subplot(2, 5, i + 1)
        plt.imshow(x_test[i])
        plt.title(f'Class: {"Dog" if y_test_classes[i] == 1 else "Cat"}')
        plt.axis('off')
    plt.show()

results(model)

# Save the model
model.save("model.hdf5")
# Out:
# C:\Users\DELL\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/100
# C:\Users\DELL\AppData\Roaming\Python\Python312\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 20s 107ms/step - accuracy: 0.5311 - loss: 0.9722 - val_accuracy: 0.5524 - val_loss: 0.7178
# Epoch 2/100
#   1/156 ━━━━━━━━━━━━━━━━━━━━ 12s 78ms/step - accuracy: 0.5625 - loss: 0.7806
# A:\Software-Application-Files\Anaconda\Lib\contextlib.py:158: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(value)
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.5625 - loss: 0.7806 - val_accuracy: 0.5520 - val_loss: 0.7180
# Epoch 3/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 17s 106ms/step - accuracy: 0.5859 - loss: 0.7176 - val_accuracy: 0.5460 - val_loss: 0.7391
# Epoch 4/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.6250 - loss: 0.6713 - val_accuracy: 0.5490 - val_loss: 0.7354
# Epoch 5/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 18s 115ms/step - accuracy: 0.6087 - loss: 0.6947 - val_accuracy: 0.6340 - val_loss: 0.6775
# Epoch 6/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.7500 - loss: 0.6873 - val_accuracy: 0.6344 - val_loss: 0.6772
# Epoch 7/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 19s 121ms/step - accuracy: 0.6178 - loss: 0.6895 - val_accuracy: 0.6366 - val_loss: 0.6705
# Epoch 8/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.6562 - loss: 0.7009 - val_accuracy: 0.6382 - val_loss: 0.6700
# Epoch 9/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 19s 120ms/step - accuracy: 0.6293 - loss: 0.6775 - val_accuracy: 0.6534 - val_loss: 0.6530
# Epoch 10/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.5625 - loss: 0.7497 - val_accuracy: 0.6538 - val_loss: 0.6524
# Epoch 11/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 19s 119ms/step - accuracy: 0.6413 - loss: 0.6701 - val_accuracy: 0.6688 - val_loss: 0.6420
# Epoch 12/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.6250 - loss: 0.7007 - val_accuracy: 0.6692 - val_loss: 0.6417
# Epoch 13/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 19s 118ms/step - accuracy: 0.6553 - loss: 0.6520 - val_accuracy: 0.6674 - val_loss: 0.6416
# Epoch 14/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.6250 - loss: 0.6029 - val_accuracy: 0.6622 - val_loss: 0.6454
# Epoch 15/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 19s 118ms/step - accuracy: 0.6600 - loss: 0.6482 - val_accuracy: 0.6622 - val_loss: 0.6424
# Epoch 16/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.6562 - loss: 0.6460 - val_accuracy: 0.6576 - val_loss: 0.6446
# Epoch 17/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 19s 119ms/step - accuracy: 0.6620 - loss: 0.6502 - val_accuracy: 0.6752 - val_loss: 0.6323
# Epoch 18/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.7188 - loss: 0.5957 - val_accuracy: 0.6760 - val_loss: 0.6312
# Epoch 19/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 19s 119ms/step - accuracy: 0.6693 - loss: 0.6386 - val_accuracy: 0.6866 - val_loss: 0.6207
# Epoch 20/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.5938 - loss: 0.6920 - val_accuracy: 0.6862 - val_loss: 0.6208
# Epoch 21/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 19s 120ms/step - accuracy: 0.6714 - loss: 0.6341 - val_accuracy: 0.6566 - val_loss: 0.6526
# Epoch 22/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - accuracy: 0.6250 - loss: 0.6223 - val_accuracy: 0.6556 - val_loss: 0.6552
# Epoch 23/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 19s 120ms/step - accuracy: 0.6788 - loss: 0.6273 - val_accuracy: 0.6862 - val_loss: 0.6210
# Epoch 24/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.6250 - loss: 0.6682 - val_accuracy: 0.6866 - val_loss: 0.6227
# Epoch 25/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 19s 120ms/step - accuracy: 0.6907 - loss: 0.6210 - val_accuracy: 0.6948 - val_loss: 0.6098
# Epoch 26/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.7188 - loss: 0.6130 - val_accuracy: 0.6942 - val_loss: 0.6120
# Epoch 27/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 19s 119ms/step - accuracy: 0.6937 - loss: 0.6117 - val_accuracy: 0.7058 - val_loss: 0.6031
# Epoch 28/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.7500 - loss: 0.5009 - val_accuracy: 0.7072 - val_loss: 0.6030
# Epoch 29/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 19s 120ms/step - accuracy: 0.6968 - loss: 0.6134 - val_accuracy: 0.7074 - val_loss: 0.5965
# Epoch 30/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.6875 - loss: 0.6696 - val_accuracy: 0.7052 - val_loss: 0.5972
# Epoch 31/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 19s 121ms/step - accuracy: 0.7008 - loss: 0.5991 - val_accuracy: 0.7072 - val_loss: 0.5909
# Epoch 32/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.6875 - loss: 0.6170 - val_accuracy: 0.7082 - val_loss: 0.5897
# Epoch 33/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 19s 119ms/step - accuracy: 0.6982 - loss: 0.5931 - val_accuracy: 0.6952 - val_loss: 0.6147
# Epoch 34/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.7500 - loss: 0.5636 - val_accuracy: 0.6940 - val_loss: 0.6203
# Epoch 35/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 18s 117ms/step - accuracy: 0.7119 - loss: 0.5869 - val_accuracy: 0.7090 - val_loss: 0.5908
# Epoch 36/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.6250 - loss: 0.7177 - val_accuracy: 0.7062 - val_loss: 0.5924
# Epoch 37/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 19s 118ms/step - accuracy: 0.7076 - loss: 0.5973 - val_accuracy: 0.7202 - val_loss: 0.5808
# Epoch 38/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.8125 - loss: 0.4915 - val_accuracy: 0.7184 - val_loss: 0.5828
# Epoch 39/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 19s 119ms/step - accuracy: 0.7044 - loss: 0.5869 - val_accuracy: 0.6594 - val_loss: 0.6842
# Epoch 40/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.7188 - loss: 0.5610 - val_accuracy: 0.6570 - val_loss: 0.6862
# Epoch 41/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 19s 119ms/step - accuracy: 0.7113 - loss: 0.5887 - val_accuracy: 0.7160 - val_loss: 0.5932
# Epoch 42/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8125 - loss: 0.5746 - val_accuracy: 0.7202 - val_loss: 0.5861
# Epoch 43/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 19s 119ms/step - accuracy: 0.7326 - loss: 0.5677 - val_accuracy: 0.7474 - val_loss: 0.5483
# Epoch 44/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.6875 - loss: 0.5628 - val_accuracy: 0.7452 - val_loss: 0.5491
# Epoch 45/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 18s 116ms/step - accuracy: 0.7067 - loss: 0.5936 - val_accuracy: 0.6992 - val_loss: 0.6130
# Epoch 46/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.7188 - loss: 0.6016 - val_accuracy: 0.6982 - val_loss: 0.6140
# Epoch 47/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 18s 116ms/step - accuracy: 0.7138 - loss: 0.5816 - val_accuracy: 0.7222 - val_loss: 0.5763
# Epoch 48/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.6875 - loss: 0.6291 - val_accuracy: 0.7248 - val_loss: 0.5713
# Epoch 49/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 18s 117ms/step - accuracy: 0.7232 - loss: 0.5619 - val_accuracy: 0.7372 - val_loss: 0.5466
# Epoch 50/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.7188 - loss: 0.5018 - val_accuracy: 0.7408 - val_loss: 0.5434
# Epoch 51/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 18s 118ms/step - accuracy: 0.7285 - loss: 0.5565 - val_accuracy: 0.7256 - val_loss: 0.5792
# Epoch 52/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.6875 - loss: 0.5439 - val_accuracy: 0.7242 - val_loss: 0.5822
# Epoch 53/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 19s 119ms/step - accuracy: 0.7459 - loss: 0.5476 - val_accuracy: 0.7432 - val_loss: 0.5512
# Epoch 54/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.7188 - loss: 0.5976 - val_accuracy: 0.7434 - val_loss: 0.5548
# Epoch 55/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 19s 120ms/step - accuracy: 0.7452 - loss: 0.5491 - val_accuracy: 0.7462 - val_loss: 0.5410
# Epoch 56/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.6875 - loss: 0.6268 - val_accuracy: 0.7486 - val_loss: 0.5399
# Epoch 57/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 19s 119ms/step - accuracy: 0.7379 - loss: 0.5528 - val_accuracy: 0.7214 - val_loss: 0.6059
# Epoch 58/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.7188 - loss: 0.6651 - val_accuracy: 0.7180 - val_loss: 0.6186
# Epoch 59/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 19s 118ms/step - accuracy: 0.7565 - loss: 0.5399 - val_accuracy: 0.7440 - val_loss: 0.5508
# Epoch 60/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.6562 - loss: 0.6180 - val_accuracy: 0.7474 - val_loss: 0.5480
# Epoch 61/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 19s 122ms/step - accuracy: 0.7534 - loss: 0.5304 - val_accuracy: 0.7120 - val_loss: 0.6152
# Epoch 62/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.8125 - loss: 0.4834 - val_accuracy: 0.7102 - val_loss: 0.6175
# Epoch 63/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 20s 125ms/step - accuracy: 0.7467 - loss: 0.5432 - val_accuracy: 0.7540 - val_loss: 0.5239
# Epoch 64/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8438 - loss: 0.4076 - val_accuracy: 0.7518 - val_loss: 0.5259
# Epoch 65/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 20s 127ms/step - accuracy: 0.7485 - loss: 0.5290 - val_accuracy: 0.7602 - val_loss: 0.5258
# Epoch 66/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.8125 - loss: 0.4810 - val_accuracy: 0.7632 - val_loss: 0.5227
# Epoch 67/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 20s 125ms/step - accuracy: 0.7694 - loss: 0.5181 - val_accuracy: 0.7176 - val_loss: 0.5762
# Epoch 68/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.6875 - loss: 0.6760 - val_accuracy: 0.7202 - val_loss: 0.5706
# Epoch 69/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 20s 124ms/step - accuracy: 0.7549 - loss: 0.5258 - val_accuracy: 0.7404 - val_loss: 0.5771
# Epoch 70/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9062 - loss: 0.3660 - val_accuracy: 0.7448 - val_loss: 0.5611
# Epoch 71/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 20s 125ms/step - accuracy: 0.7648 - loss: 0.5148 - val_accuracy: 0.7636 - val_loss: 0.5078
# Epoch 72/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.6562 - loss: 0.6696 - val_accuracy: 0.7630 - val_loss: 0.5071
# Epoch 73/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 20s 125ms/step - accuracy: 0.7630 - loss: 0.5070 - val_accuracy: 0.7666 - val_loss: 0.5173
# Epoch 74/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.8438 - loss: 0.5116 - val_accuracy: 0.7652 - val_loss: 0.5187
# Epoch 75/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 19s 122ms/step - accuracy: 0.7725 - loss: 0.5058 - val_accuracy: 0.7634 - val_loss: 0.5220
# Epoch 76/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.8750 - loss: 0.4117 - val_accuracy: 0.7602 - val_loss: 0.5295
# Epoch 77/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 19s 124ms/step - accuracy: 0.7761 - loss: 0.4906 - val_accuracy: 0.7602 - val_loss: 0.5303
# Epoch 78/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.8750 - loss: 0.5310 - val_accuracy: 0.7628 - val_loss: 0.5230
# Epoch 79/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 19s 123ms/step - accuracy: 0.7807 - loss: 0.4942 - val_accuracy: 0.7720 - val_loss: 0.5071
# Epoch 80/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.7500 - loss: 0.4915 - val_accuracy: 0.7702 - val_loss: 0.5066
# Epoch 81/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 19s 122ms/step - accuracy: 0.7719 - loss: 0.4995 - val_accuracy: 0.7726 - val_loss: 0.5158
# Epoch 82/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.6875 - loss: 0.5463 - val_accuracy: 0.7720 - val_loss: 0.5199
# Epoch 83/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 20s 125ms/step - accuracy: 0.7895 - loss: 0.4719 - val_accuracy: 0.7084 - val_loss: 0.6689
# Epoch 84/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9062 - loss: 0.4312 - val_accuracy: 0.7052 - val_loss: 0.6771
# Epoch 85/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 20s 127ms/step - accuracy: 0.7651 - loss: 0.5041 - val_accuracy: 0.7396 - val_loss: 0.5696
# Epoch 86/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8750 - loss: 0.3631 - val_accuracy: 0.7404 - val_loss: 0.5690
# Epoch 87/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 20s 127ms/step - accuracy: 0.7537 - loss: 0.5070 - val_accuracy: 0.7724 - val_loss: 0.4987
# Epoch 88/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.7500 - loss: 0.5288 - val_accuracy: 0.7704 - val_loss: 0.5019
# Epoch 89/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 20s 127ms/step - accuracy: 0.7933 - loss: 0.4750 - val_accuracy: 0.7716 - val_loss: 0.5235
# Epoch 90/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - accuracy: 0.8438 - loss: 0.4922 - val_accuracy: 0.7702 - val_loss: 0.5288
# Epoch 91/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 20s 128ms/step - accuracy: 0.7783 - loss: 0.4917 - val_accuracy: 0.7802 - val_loss: 0.4993
# Epoch 92/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8125 - loss: 0.4034 - val_accuracy: 0.7810 - val_loss: 0.5005
# Epoch 93/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 20s 128ms/step - accuracy: 0.7822 - loss: 0.4757 - val_accuracy: 0.7794 - val_loss: 0.4983
# Epoch 94/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.9688 - loss: 0.2539 - val_accuracy: 0.7788 - val_loss: 0.4990
# Epoch 95/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 21s 131ms/step - accuracy: 0.7923 - loss: 0.4754 - val_accuracy: 0.7578 - val_loss: 0.5632
# Epoch 96/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.7188 - loss: 0.5275 - val_accuracy: 0.7536 - val_loss: 0.5715
# Epoch 97/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 20s 127ms/step - accuracy: 0.7850 - loss: 0.4728 - val_accuracy: 0.7830 - val_loss: 0.5026
# Epoch 98/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.8750 - loss: 0.3545 - val_accuracy: 0.7800 - val_loss: 0.5039
# Epoch 99/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 20s 128ms/step - accuracy: 0.7781 - loss: 0.4851 - val_accuracy: 0.7668 - val_loss: 0.5146
# Epoch 100/100
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.9062 - loss: 0.3881 - val_accuracy: 0.7680 - val_loss: 0.5113
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.7832 - loss: 0.5058
# Test set loss: 0.5031760931015015
# Test set accuracy: 78.70000004768372
# Classification Report:
#               precision  recall  f1-score   support
# Cat            0.802105   0.762  0.781538  1000.000
# Dog            0.773333   0.812  0.792195  1000.000
# accuracy       0.787000   0.787  0.787000     0.787
# macro avg      0.787719   0.787  0.786867  2000.000
# weighted avg   0.787719   0.787  0.786867  2000.000
#
# Model Summary:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 32, 32, 32)          │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 32, 32, 32)          │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 32, 32, 32)          │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 32, 32, 32)          │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 16, 16, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 16, 16, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 16, 16, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 16, 16, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 16, 16, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 16, 16, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 8, 8, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 8, 8, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 8, 8, 128)           │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_4                │ (None, 8, 8, 128)           │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 8, 8, 128)           │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_5                │ (None, 8, 8, 128)           │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 4, 4, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 4, 4, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 2048)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │         262,272 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │             129 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,101,508 (4.20 MB)
#  Trainable params: 550,305 (2.10 MB)
#  Non-trainable params: 896 (3.50 KB)
#  Optimizer params: 550,307 (2.10 MB)
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
