# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, Flatten, BatchNormalization
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import SGD
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# Load and preprocess data
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

# Class names for CIFAR-10
class_names = ['Airplane', 'Automobile', 'Bird', 'Cat', 'Deer', 'Dog', 'Frog', 'Horse', 'Ship', 'Truck']

print('x_train shape:', x_train.shape)
print('y_train shape:', y_train.shape)

def normalize(x):
    x = x.astype('float32') / 255.0
    return x

x_train = normalize(x_train)
x_test = normalize(x_test)

x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.5, random_state=0)
x_val = normalize(x_val)

y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)
y_val = to_categorical(y_val, 10)

datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True
)
datagen.fit(x_train)

# Model definition
weight_decay = 1e-4
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', padding='same', kernel_regularizer=tf.keras.regularizers.l2(weight_decay), input_shape=(32, 32, 3)),
    BatchNormalization(),
    Conv2D(32, (3, 3), activation='relu', kernel_regularizer=tf.keras.regularizers.l2(weight_decay), padding='same'),
    BatchNormalization(),
    MaxPooling2D((2, 2)),
    Dropout(0.2),
    Conv2D(64, (3, 3), activation='relu', kernel_regularizer=tf.keras.regularizers.l2(weight_decay), padding='same'),
    BatchNormalization(),
    Conv2D(64, (3, 3), activation='relu', kernel_regularizer=tf.keras.regularizers.l2(weight_decay), padding='same'),
    BatchNormalization(),
    MaxPooling2D((2, 2)),
    Dropout(0.3),
    Conv2D(128, (3, 3), activation='relu', kernel_regularizer=tf.keras.regularizers.l2(weight_decay), padding='same'),
    BatchNormalization(),
    Conv2D(128, (3, 3), activation='relu', kernel_regularizer=tf.keras.regularizers.l2(weight_decay), padding='same'),
    BatchNormalization(),
    MaxPooling2D((2, 2)),
    Dropout(0.3),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(10, activation='softmax')
])

# Compile the model
opt = SGD(learning_rate=0.001, momentum=0.9)
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

# Training and evaluation
def results(model):
    epoch = 100
    r = model.fit(datagen.flow(x_train, y_train, batch_size=32), epochs=epoch, steps_per_epoch=len(x_train) // 32, validation_data=(x_val, y_val), verbose=1)
    
    # Evaluate model
    y_pred = model.predict(x_test)
    y_test_classes = np.argmax(y_test, axis=1)
    y_pred_classes = np.argmax(y_pred, axis=1)
    
    # Confusion Matrix
    conf_matrix = confusion_matrix(y_test_classes, y_pred_classes)
    
    # Classification Report
    class_report = classification_report(y_test_classes, y_pred_classes, target_names=class_names, output_dict=True)

    # Model Evaluation
    acc = model.evaluate(x_test, y_test)
    print("Test set loss:", acc[0])
    print("Test set accuracy:", acc[1] * 100)
    
    # Plot accuracy
    epoch_range = range(1, epoch + 1)
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(epoch_range, r.history['accuracy'])
    plt.plot(epoch_range, r.history['val_accuracy'])
    plt.title('Classification Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='lower right')
    
    # Plot loss
    plt.subplot(1, 2, 2)
    plt.plot(epoch_range, r.history['loss'])
    plt.plot(epoch_range, r.history['val_loss'])
    plt.title('Model Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='lower right')
    plt.show()

    # Confusion Matrix Heatmap
    plt.figure(figsize=(8, 6))
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')
    plt.show()
    
    # Classification Report
    report_df = pd.DataFrame(class_report).transpose()
    print("\nClassification Report:")
    print(report_df)
    
    # Model Summary
    print("\nModel Summary:")
    model.summary()

    # Display some images from the test set
    plt.figure(figsize=(10, 10))
    for i in range(10):
        plt.subplot(2, 5, i + 1)
        plt.imshow(x_test[i])
        plt.title(f'Class: {class_names[y_test_classes[i]]}')
        plt.axis('off')
    plt.show()

results(model)

# Save the model
model.save("model.h5")
# Out:
# x_train shape: (50000, 32, 32, 3)
# y_train shape: (50000, 1)
# Epoch 1/100
# C:\Users\DELL\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# C:\Users\DELL\AppData\Roaming\Python\Python312\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 84s 103ms/step - accuracy: 0.2620 - loss: 2.1820 - val_accuracy: 0.0997 - val_loss: 3.7725
# Epoch 2/100
#   1/781 ━━━━━━━━━━━━━━━━━━━━ 1:13 94ms/step - accuracy: 0.5312 - loss: 1.3793
# A:\Software-Application-Files\Anaconda\Lib\contextlib.py:158: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(value)
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.5312 - loss: 1.3793 - val_accuracy: 0.0991 - val_loss: 3.8272
# Epoch 3/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 84s 107ms/step - accuracy: 0.4285 - loss: 1.5934 - val_accuracy: 0.0994 - val_loss: 3.7606
# Epoch 4/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.4062 - loss: 1.6156 - val_accuracy: 0.0994 - val_loss: 3.7850
# Epoch 5/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 82s 104ms/step - accuracy: 0.4894 - loss: 1.4447 - val_accuracy: 0.0991 - val_loss: 4.0631
# Epoch 6/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.5938 - loss: 1.0974 - val_accuracy: 0.0991 - val_loss: 4.0845
# Epoch 7/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 88s 113ms/step - accuracy: 0.5239 - loss: 1.3567 - val_accuracy: 0.0998 - val_loss: 3.7718
# Epoch 8/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 17s 21ms/step - accuracy: 0.5938 - loss: 1.4428 - val_accuracy: 0.0998 - val_loss: 3.7921
# Epoch 9/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 87s 111ms/step - accuracy: 0.5512 - loss: 1.2841 - val_accuracy: 0.0994 - val_loss: 3.5040
# Epoch 10/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 15s 19ms/step - accuracy: 0.5312 - loss: 1.4842 - val_accuracy: 0.0994 - val_loss: 3.5146
# Epoch 11/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 89s 113ms/step - accuracy: 0.5738 - loss: 1.2210 - val_accuracy: 0.0994 - val_loss: 4.4991
# Epoch 12/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 15s 20ms/step - accuracy: 0.4375 - loss: 1.4077 - val_accuracy: 0.0994 - val_loss: 4.3305
# Epoch 13/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 90s 115ms/step - accuracy: 0.5929 - loss: 1.1695 - val_accuracy: 0.0991 - val_loss: 4.4496
# Epoch 14/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 15s 19ms/step - accuracy: 0.5625 - loss: 1.2522 - val_accuracy: 0.0991 - val_loss: 4.4877
# Epoch 15/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 95s 122ms/step - accuracy: 0.6082 - loss: 1.1271 - val_accuracy: 0.0991 - val_loss: 3.6384
# Epoch 16/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 16s 20ms/step - accuracy: 0.6562 - loss: 0.8673 - val_accuracy: 0.0991 - val_loss: 3.5975
# Epoch 17/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 91s 116ms/step - accuracy: 0.6285 - loss: 1.0798 - val_accuracy: 0.0991 - val_loss: 4.5325
# Epoch 18/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 15s 19ms/step - accuracy: 0.6250 - loss: 1.0615 - val_accuracy: 0.0991 - val_loss: 4.5748
# Epoch 19/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 88s 113ms/step - accuracy: 0.6425 - loss: 1.0423 - val_accuracy: 0.0991 - val_loss: 4.4905
# Epoch 20/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 16s 20ms/step - accuracy: 0.6875 - loss: 1.1563 - val_accuracy: 0.0991 - val_loss: 4.4866
# Epoch 21/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 95s 122ms/step - accuracy: 0.6515 - loss: 1.0092 - val_accuracy: 0.0991 - val_loss: 3.4695
# Epoch 22/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.7812 - loss: 0.5842 - val_accuracy: 0.0991 - val_loss: 3.4715
# Epoch 23/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 88s 112ms/step - accuracy: 0.6542 - loss: 0.9919 - val_accuracy: 0.0991 - val_loss: 4.0462
# Epoch 24/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 15s 18ms/step - accuracy: 0.6875 - loss: 0.7430 - val_accuracy: 0.0991 - val_loss: 4.0375
# Epoch 25/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 88s 112ms/step - accuracy: 0.6743 - loss: 0.9612 - val_accuracy: 0.0991 - val_loss: 3.9906
# Epoch 26/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 15s 19ms/step - accuracy: 0.5938 - loss: 1.0297 - val_accuracy: 0.0991 - val_loss: 4.0141
# Epoch 27/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 90s 115ms/step - accuracy: 0.6804 - loss: 0.9360 - val_accuracy: 0.0991 - val_loss: 3.7319
# Epoch 28/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.7188 - loss: 0.8243 - val_accuracy: 0.0991 - val_loss: 3.7271
# Epoch 29/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 88s 113ms/step - accuracy: 0.6849 - loss: 0.9220 - val_accuracy: 0.0991 - val_loss: 4.0244
# Epoch 30/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.6250 - loss: 1.0620 - val_accuracy: 0.0991 - val_loss: 4.0311
# Epoch 31/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 88s 112ms/step - accuracy: 0.6932 - loss: 0.9006 - val_accuracy: 0.0994 - val_loss: 4.9214
# Epoch 32/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 15s 19ms/step - accuracy: 0.6875 - loss: 0.8649 - val_accuracy: 0.0994 - val_loss: 4.9182
# Epoch 33/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 89s 114ms/step - accuracy: 0.6985 - loss: 0.8857 - val_accuracy: 0.0991 - val_loss: 3.3924
# Epoch 34/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.5625 - loss: 0.9809 - val_accuracy: 0.0992 - val_loss: 3.4176
# Epoch 35/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 88s 113ms/step - accuracy: 0.7115 - loss: 0.8551 - val_accuracy: 0.0994 - val_loss: 4.5027
# Epoch 36/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.7188 - loss: 0.6948 - val_accuracy: 0.0994 - val_loss: 4.5171
# Epoch 37/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 88s 112ms/step - accuracy: 0.7170 - loss: 0.8320 - val_accuracy: 0.0994 - val_loss: 4.3623
# Epoch 38/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.5938 - loss: 1.0273 - val_accuracy: 0.0994 - val_loss: 4.3701
# Epoch 39/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 88s 112ms/step - accuracy: 0.7188 - loss: 0.8274 - val_accuracy: 0.0986 - val_loss: 3.7490
# Epoch 40/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 15s 19ms/step - accuracy: 0.7812 - loss: 0.7318 - val_accuracy: 0.0986 - val_loss: 3.7307
# Epoch 41/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 87s 112ms/step - accuracy: 0.7200 - loss: 0.8116 - val_accuracy: 0.0991 - val_loss: 3.2320
# Epoch 42/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.6562 - loss: 1.2259 - val_accuracy: 0.0991 - val_loss: 3.2379
# Epoch 43/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 88s 112ms/step - accuracy: 0.7318 - loss: 0.7966 - val_accuracy: 0.0994 - val_loss: 3.2698
# Epoch 44/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.7188 - loss: 0.9822 - val_accuracy: 0.0994 - val_loss: 3.3007
# Epoch 45/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 89s 113ms/step - accuracy: 0.7392 - loss: 0.7762 - val_accuracy: 0.0994 - val_loss: 3.4972
# Epoch 46/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 15s 19ms/step - accuracy: 0.7188 - loss: 0.8942 - val_accuracy: 0.0994 - val_loss: 3.5086
# Epoch 47/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 88s 112ms/step - accuracy: 0.7422 - loss: 0.7825 - val_accuracy: 0.0994 - val_loss: 4.3216
# Epoch 48/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 15s 19ms/step - accuracy: 0.7500 - loss: 0.6908 - val_accuracy: 0.0994 - val_loss: 4.3258
# Epoch 49/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 88s 112ms/step - accuracy: 0.7393 - loss: 0.7759 - val_accuracy: 0.0994 - val_loss: 4.2170
# Epoch 50/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 15s 19ms/step - accuracy: 0.6875 - loss: 0.8405 - val_accuracy: 0.0994 - val_loss: 4.2417
# Epoch 51/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 88s 113ms/step - accuracy: 0.7465 - loss: 0.7541 - val_accuracy: 0.0994 - val_loss: 3.6492
# Epoch 52/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 15s 18ms/step - accuracy: 0.7500 - loss: 0.7378 - val_accuracy: 0.0994 - val_loss: 3.6364
# Epoch 53/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 87s 112ms/step - accuracy: 0.7424 - loss: 0.7640 - val_accuracy: 0.1642 - val_loss: 4.2827
# Epoch 54/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 19s 24ms/step - accuracy: 0.7812 - loss: 0.6855 - val_accuracy: 0.1048 - val_loss: 4.2914
# Epoch 55/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 87s 112ms/step - accuracy: 0.7591 - loss: 0.7395 - val_accuracy: 0.0986 - val_loss: 4.3797
# Epoch 56/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.6562 - loss: 1.1079 - val_accuracy: 0.0986 - val_loss: 4.4138
# Epoch 57/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 87s 112ms/step - accuracy: 0.7563 - loss: 0.7326 - val_accuracy: 0.0986 - val_loss: 3.9456
# Epoch 58/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 15s 19ms/step - accuracy: 0.8438 - loss: 0.5454 - val_accuracy: 0.0986 - val_loss: 3.9496
# Epoch 59/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 87s 112ms/step - accuracy: 0.7615 - loss: 0.7193 - val_accuracy: 0.0994 - val_loss: 4.2973
# Epoch 60/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.7500 - loss: 0.7739 - val_accuracy: 0.0994 - val_loss: 4.3349
# Epoch 61/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 88s 112ms/step - accuracy: 0.7638 - loss: 0.7111 - val_accuracy: 0.0991 - val_loss: 3.6102
# Epoch 62/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.7188 - loss: 0.6781 - val_accuracy: 0.0991 - val_loss: 3.5894
# Epoch 63/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 88s 112ms/step - accuracy: 0.7660 - loss: 0.7058 - val_accuracy: 0.0994 - val_loss: 4.8393
# Epoch 64/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.8438 - loss: 0.5926 - val_accuracy: 0.0994 - val_loss: 4.7893
# Epoch 65/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 96s 123ms/step - accuracy: 0.7669 - loss: 0.6962 - val_accuracy: 0.0992 - val_loss: 3.4319
# Epoch 66/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 15s 18ms/step - accuracy: 0.8438 - loss: 0.5327 - val_accuracy: 0.1292 - val_loss: 3.4448
# Epoch 67/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 90s 115ms/step - accuracy: 0.7724 - loss: 0.6835 - val_accuracy: 0.0994 - val_loss: 4.2605
# Epoch 68/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 15s 19ms/step - accuracy: 0.8750 - loss: 0.3465 - val_accuracy: 0.0994 - val_loss: 4.2638
# Epoch 69/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 91s 116ms/step - accuracy: 0.7697 - loss: 0.6785 - val_accuracy: 0.0991 - val_loss: 4.5015
# Epoch 70/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 15s 19ms/step - accuracy: 0.9062 - loss: 0.4337 - val_accuracy: 0.0991 - val_loss: 4.5044
# Epoch 71/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 92s 117ms/step - accuracy: 0.7837 - loss: 0.6630 - val_accuracy: 0.0991 - val_loss: 3.5776
# Epoch 72/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 15s 19ms/step - accuracy: 0.7500 - loss: 0.6995 - val_accuracy: 0.0991 - val_loss: 3.5859
# Epoch 73/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 91s 117ms/step - accuracy: 0.7787 - loss: 0.6675 - val_accuracy: 0.0994 - val_loss: 4.2019
# Epoch 74/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 15s 19ms/step - accuracy: 0.8750 - loss: 0.4502 - val_accuracy: 0.0994 - val_loss: 4.2048
# Epoch 75/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 95s 121ms/step - accuracy: 0.7842 - loss: 0.6532 - val_accuracy: 0.1002 - val_loss: 4.4092
# Epoch 76/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.7812 - loss: 0.5365 - val_accuracy: 0.1010 - val_loss: 4.3987
# Epoch 77/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 90s 115ms/step - accuracy: 0.7901 - loss: 0.6413 - val_accuracy: 0.0994 - val_loss: 4.5257
# Epoch 78/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 15s 19ms/step - accuracy: 0.8438 - loss: 0.4762 - val_accuracy: 0.0994 - val_loss: 4.5151
# Epoch 79/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 90s 115ms/step - accuracy: 0.7826 - loss: 0.6560 - val_accuracy: 0.0994 - val_loss: 3.8703
# Epoch 80/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 15s 19ms/step - accuracy: 0.7812 - loss: 0.6735 - val_accuracy: 0.0994 - val_loss: 3.8461
# Epoch 81/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 91s 116ms/step - accuracy: 0.7857 - loss: 0.6465 - val_accuracy: 0.0994 - val_loss: 4.5092
# Epoch 82/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.8438 - loss: 0.3968 - val_accuracy: 0.0994 - val_loss: 4.5296
# Epoch 83/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 91s 116ms/step - accuracy: 0.7948 - loss: 0.6228 - val_accuracy: 0.0991 - val_loss: 4.8748
# Epoch 84/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 15s 19ms/step - accuracy: 0.6875 - loss: 1.0346 - val_accuracy: 0.0991 - val_loss: 4.8449
# Epoch 85/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 91s 116ms/step - accuracy: 0.8004 - loss: 0.6009 - val_accuracy: 0.0991 - val_loss: 4.1220
# Epoch 86/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.8125 - loss: 0.4397 - val_accuracy: 0.0991 - val_loss: 4.1182
# Epoch 87/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 91s 116ms/step - accuracy: 0.7908 - loss: 0.6285 - val_accuracy: 0.0994 - val_loss: 3.8609
# Epoch 88/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 15s 19ms/step - accuracy: 0.8125 - loss: 0.7707 - val_accuracy: 0.0994 - val_loss: 3.8680
# Epoch 89/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 92s 118ms/step - accuracy: 0.8004 - loss: 0.6031 - val_accuracy: 0.0994 - val_loss: 4.3626
# Epoch 90/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 15s 20ms/step - accuracy: 0.7188 - loss: 0.6988 - val_accuracy: 0.0994 - val_loss: 4.3817
# Epoch 91/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 94s 121ms/step - accuracy: 0.7986 - loss: 0.6033 - val_accuracy: 0.0994 - val_loss: 3.9788
# Epoch 92/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 16s 20ms/step - accuracy: 0.7500 - loss: 0.5521 - val_accuracy: 0.0994 - val_loss: 3.9821
# Epoch 93/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 93s 119ms/step - accuracy: 0.8028 - loss: 0.6018 - val_accuracy: 0.0994 - val_loss: 5.2519
# Epoch 94/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 15s 20ms/step - accuracy: 0.8125 - loss: 0.5813 - val_accuracy: 0.0994 - val_loss: 5.2724
# Epoch 95/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 94s 120ms/step - accuracy: 0.8020 - loss: 0.6078 - val_accuracy: 0.0994 - val_loss: 3.4828
# Epoch 96/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 15s 19ms/step - accuracy: 0.8438 - loss: 0.6047 - val_accuracy: 0.0994 - val_loss: 3.4931
# Epoch 97/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 98s 125ms/step - accuracy: 0.8019 - loss: 0.5967 - val_accuracy: 0.0994 - val_loss: 3.8145
# Epoch 98/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 17s 22ms/step - accuracy: 0.8750 - loss: 0.3929 - val_accuracy: 0.0994 - val_loss: 3.8382
# Epoch 99/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 94s 120ms/step - accuracy: 0.8042 - loss: 0.6036 - val_accuracy: 0.0994 - val_loss: 4.1948
# Epoch 100/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 15s 19ms/step - accuracy: 0.9062 - loss: 0.3440 - val_accuracy: 0.0994 - val_loss: 4.1872
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 27ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.7802 - loss: 0.6985
# Test set loss: 0.7036941051483154
# Test set accuracy: 78.07000279426575
# Classification Report:
#               precision  recall  f1-score     support
# Airplane       0.869663  0.7740  0.819048   1000.0000
# Automobile     0.919305  0.9000  0.909550   1000.0000
# Bird           0.780806  0.6590  0.714751   1000.0000
# Cat            0.688725  0.5620  0.618943   1000.0000
# Deer           0.699821  0.7810  0.738185   1000.0000
# Dog            0.837461  0.5410  0.657351   1000.0000
# Frog           0.582371  0.9580  0.724386   1000.0000
# Horse          0.841401  0.8170  0.829021   1000.0000
# Ship           0.901222  0.8850  0.893037   1000.0000
# Truck          0.837084  0.9300  0.881099   1000.0000
# accuracy       0.780700  0.7807  0.780700      0.7807
# macro avg      0.795786  0.7807  0.778537  10000.0000
# weighted avg   0.795786  0.7807  0.778537  10000.0000
#
# Model Summary:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 32, 32, 32)          │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 32, 32, 32)          │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 32, 32, 32)          │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 32, 32, 32)          │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 16, 16, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 16, 16, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 16, 16, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 16, 16, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 16, 16, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 16, 16, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 8, 8, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 8, 8, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 8, 8, 128)           │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_4                │ (None, 8, 8, 128)           │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 8, 8, 128)           │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_5                │ (None, 8, 8, 128)           │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 4, 4, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 4, 4, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 2048)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │         262,272 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 10)                  │           1,290 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,103,830 (4.21 MB)
#  Trainable params: 551,466 (2.10 MB)
#  Non-trainable params: 896 (3.50 KB)
#  Optimizer params: 551,468 (2.10 MB)
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
